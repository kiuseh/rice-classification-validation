# %% [markdown]
# # Rice variety classification
#
# This output-free notebook uses the same validated functions as `train.py`. The final reported metrics are generated from a deterministic stratified split.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "rice_model.py").is_file():
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))

from rice_model import load_dataset, run_experiment

# %% [markdown]
# ## Load and validate the official dataset copy

# %%
data_path = PROJECT_ROOT / "data" / "Rice_Cammeo_Osmancik.xlsx"
data = load_dataset(data_path)
data.head()

# %%
data.info()
data["Class"].value_counts()

# %% [markdown]
# ## Reproduce cross-validation and holdout metrics
#
# Cross-validation is restricted to the training partition. The 20% holdout is used only for the final evaluation.

# %%
results, model = run_experiment(data_path)
{
    "training_cv": results["cross_validation_on_training_partition"],
    "holdout": {
        key: results["holdout"][key]
        for key in ("accuracy", "balanced_accuracy", "macro_f1", "confusion_matrix")
    },
}
